# %%
import pandas as pd

df = pd.read_csv('/content/food.csv')

df_food = df.copy()
df_food.head()
# Out:
#    Unnamed: 0 f_id                  item veg_or_non_veg
# 0           0  fd0     Aloo Tikki Burger            Veg
# 1           1  fd1     Veg Creamy Burger            Veg
# 2           2  fd2   Cheese Burst Burger            Veg
# 3           3  fd3  Paneer Creamy Burger            Veg
# 4           4  fd4        Maxican Burger            Veg

# %%
df_food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371561 entries, 0 to 371560
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      371561 non-null  int64
#  1   f_id            371561 non-null  object
#  2   item            371560 non-null  object
#  3   veg_or_non_veg  371560 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 11.3+ MB

# %%
df_food.columns
# Out:
# Index(['Unnamed: 0', 'f_id', 'item', 'veg_or_non_veg'], dtype='object')

# %%
df_food[df_food.isnull().any(axis=1)]
# Out:
#         Unnamed: 0      f_id item veg_or_non_veg
# 166711      166711  fd413746  NaN            NaN

# %%
df_food.isnull().sum()
# Out:
# Unnamed: 0        0
# f_id              0
# item              1
# veg_or_non_veg    1
# dtype: int64

# %%
df_food['veg_or_non_veg'].unique()
# Out:
# array(['Veg', 'Non-veg', nan], dtype=object)

# %%
df_food['veg_or_non_veg'].value_counts()
# Out:
# veg_or_non_veg
# Veg        270776
# Non-veg    100784
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import pandas as pd

veg_counts = df_food['veg_or_non_veg'].value_counts()

# Create the pie chart
plt.figure(figsize=(6, 6))  # Adjust figure size if needed
plt.pie(veg_counts, labels=veg_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Veg and Non-Veg')
plt.show()

# %%
df_menu = pd.read_csv('/content/menu.csv')
df_menu.head()
# Out:
#    Unnamed: 0 menu_id      r_id      f_id           cuisine  price
# 0           0     mn0  567335.0       fd0  Beverages,Pizzas   40.0
# 1           1     mn0  567335.0  fd669322  Beverages,Pizzas   40.0
# 2           2   mn328  158203.0       fd0         Beverages   65.0
# 3           3   mn328  158203.0  fd669322         Beverages   65.0
# 4           4   mn449  158203.0       fd0         Beverages   65.0

# %%
df_menu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251051 entries, 0 to 251050
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  251051 non-null  int64
#  1   menu_id     251051 non-null  object
#  2   r_id        251050 non-null  float64
#  3   f_id        251050 non-null  object
#  4   cuisine     251050 non-null  object
#  5   price       251050 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 11.5+ MB

# %%
df_menu.columns
# Out:
# Index(['Unnamed: 0', 'menu_id', 'r_id', 'f_id', 'cuisine', 'price'], dtype='object')

# %%
df_menu.isnull().sum()
# Out:
# Unnamed: 0    0
# menu_id       0
# r_id          1
# f_id          1
# cuisine       1
# price         1
# dtype: int64

# %%
df_menu['cuisine'].unique()
# Out:
# array(['Beverages,Pizzas', 'Beverages', 'Continental', 'Juices,Beverages',
#        'Indian', 'Pizzas,Beverages', 'Chinese,Pizzas',
#        'North Indian,Fast Food', 'Bakery,Beverages', 'Bakery,Pizzas',
#        'Pizzas,Pastas', 'Pizzas,Snacks', 'Indian,Chinese',
#        'Beverages,Fast Food', 'Burgers,Street Food', 'Pizzas,Burgers',
#        'North Indian,Lucknowi', 'Fast Food,Pizzas', 'American,Pizzas',
#        'Bakery,Indian', 'North Indian,Chinese', 'Chinese,Fast Food',
#        'Chinese,Desserts', 'Italian,Beverages', 'Indian,Continental',
#        'Italian', 'Desserts,Sweets', 'Indian,Fast Food',
#        'Chinese,South Indian', 'Street Food,Snacks', 'Fast Food',
#        'Maharashtrian,North Indian', 'Snacks,Fast Food',
#        'Street Food,Fast Food', 'Bakery,Continental', 'Snacks',
#        'Fast Food,Beverages', 'American,Snacks', 'Italian,Fast Food',
#        'Ice Cream,American', 'Pan-Asian,Chinese', 'Fast Food,Snacks',
#        'Snacks,Italian', 'Italian-American,Fast Food', 'Italian,Chinese',
#        'American,Fast Food', 'Fast Food,North Indian', 'Pizzas',
#        'Pizzas,Fast Food', 'Combo', 'Bakery', 'Italian,Indian',
#        'Cafe,Fast Food', 'Beverages,Italian-American', 'Beverages,Snacks',
#        'Street Food,Continental', 'Desserts', 'Street Food,Desserts',
#        'Street Food', 'North Indian', 'North Indian,Snacks',
#        'Fast Food,Chinese', 'Fast Food,Italian', 'Beverages,Chaat',
#        'Fast Food,American', 'American,Indian', 'Pizzas,Indian',
#        'Fast Food,Street Food', 'Pizzas,American', 'Chinese,American',
#        'Continental,Beverages', 'Chinese,Indian', 'Indian,Snacks',
#        'Pizzas,North Indian', 'Snacks,Indian', 'Pizzas,Italian',
#        'Snacks,Pizzas', 'Sweets,Snacks', 'Ice Cream,Snacks',
#        'Waffle,Fast Food', 'Beverages,Desserts', 'Continental,Pizzas',
#        'Chinese,Beverages', 'North Indian,Biryani', 'Thalis,Indian',
#        'Pizzas,Street Food', 'Fast Food,Waffle', 'Beverages,Chinese',
#        'Italian,American', 'Chinese', 'North Indian,South Indian',
#        'North Indian,Burgers', 'Pizzas,Biryani',
#        'South Indian,North Indian', 'Bakery,Desserts',
#        'South Indian,Thalis', 'Burgers', 'American,Beverages',
#        'Mughlai,Biryani', 'Bakery,American', 'Ice Cream,Beverages',
#        'Biryani,Fast Food', 'North Indian,Punjabi', 'Chinese,Snacks',
#        'South Indian,Fast Food', 'Pizzas,Bakery', 'Bakery,Italian',
#        'Sweets,Desserts', 'Desserts,Beverages', 'Fast Food,Chaat',
#        'Continental,Italian', 'Snacks,Chinese', 'Italian,Pastas',
#        'Healthy Food,Salads', 'Beverages,Italian', 'Italian,Pizzas',
#        'Pizzas,Italian-American', 'Chinese,North Indian',
#        'North Indian,Indian', 'Pizzas,Chinese', 'Ice Cream',
#        'Burgers,Fast Food', 'Cafe', 'Fast Food,Bakery',
#        'North Indian,Arabian', 'Indian,South Indian',
#        'Italian-American,Beverages', 'North Indian,Combo',
#        'Italian-American,Combo', 'Indian,North Indian', 'Chinese,Burgers',
#        'Burgers,Chinese', 'Afghani,Italian', 'Snacks,American',
#        'Fast Food,Pastas', 'Salads,Beverages', 'Pastas,Pizzas',
#        'American,Italian', 'Italian,Continental', 'South Indian,Desserts',
#        'Chinese,Italian', 'Biryani,Chinese', 'Chaat', 'Beverages,Juices',
#        'Snacks,Maharashtrian', 'Burgers,Snacks', 'American,Combo',
#        'Ice Cream,Juices', 'Indian,Pizzas', 'Chaat,Snacks',
#        'Snacks,Beverages', 'Continental,Pastas', 'Fast Food,South Indian',
#        'Beverages,Indian', 'American', 'Cafe,Indian', 'Grill,Fast Food',
#        'Chinese,Continental', 'Beverages,Continental', 'Pizzas,Desserts',
#        'Continental,North Indian', 'Continental,Asian',
#        'American,Continental', 'Continental,Indian',
#        'Arabian,North Indian', 'Burgers,Pizzas', 'American,Chinese',
#        'Indian,Italian', 'Pizzas,Ice Cream', 'Continental,American',
#        'Fast Food,Italian-American', 'Italian-American,Chinese',
#        'Pizzas,Continental', 'Beverages,Ice Cream', 'Sweets,Street Food',
#        'North Indian,Bakery', 'Snacks,South Indian', 'Snacks,Continental',
#        'Cafe,Beverages', 'Italian-American', 'South Indian,Chinese',
#        'Healthy Food,Fast Food', 'North Indian,Street Food',
#        'Chinese,Tandoor', 'North Indian,Mughlai', 'Biryani,North Indian',
#        'Desserts,American', 'Sweets,Bakery', 'Sweets,Beverages',
#        'Bakery,Chinese', 'Chinese,Bakery', 'North Indian,Beverages',
#        'Chinese,Biryani', 'South Indian', 'Indian,Arabian',
#        'European,Italian', 'Sweets,North Indian', 'Bakery,Fast Food',
#        'Continental,Chinese', 'North Indian,Italian',
#        'North Indian,Mexican', 'South Indian,Indian', 'Gujarati',
#        'Punjabi,Chinese', 'Street Food,Chinese', 'Biryani,Indian',
#        'Chinese,Mughlai', 'American,North Indian',
#        'South Indian,Beverages', 'North Indian,Maharashtrian',
#        'Street Food,South Indian', 'North Indian,Tandoor',
#        'Indian,Punjabi', 'Pizzas,Tandoor', 'North Indian,Desserts',
#        'Italian,Snacks', 'Indian,Bengali', 'Indian,Afghani',
#        'Asian,Chinese', 'Chinese,Asian', 'Indian,Mexican',
#        'Chinese,Pastas', 'Chaat,South Indian', 'Indian,Beverages',
#        'North Indian,Asian', 'North Indian,Healthy Food',
#        'Bengali,Mughlai', 'Bengali,North Indian', 'Beverages,Street Food',
#        'North Indian,Continental', 'Mexican,Chinese', 'North Indian,Thai',
#        'Thalis,Punjabi', 'Chinese,Thai', 'Tandoor,North Indian',
#        'Punjabi,Italian', 'Street Food,Pizzas', 'Combo,Chinese',
#        'Punjabi,Biryani', 'Oriental,Pizzas', 'Punjabi', 'Chinese,Punjabi',
#        'North Indian,Sweets', 'Chinese,Street Food', 'Combo,Indian',
#        'Street Food,Chaat', 'Cafe,American', 'Tandoor,Mughlai',
#        'Mexican,Mediterranean', 'Continental,Tibetan', 'Tibetan,Chinese',
#        'Mexican,North Indian', 'Punjabi,Gujarati', 'Gujarati,Chinese',
#        'Combo,Salads', 'Japanese,Thai', 'Biryani,Punjabi',
#        'Gujarati,Indian', 'Thalis,Gujarati', 'Snacks,Sweets',
#        'South Indian,Italian-American', 'North Indian,Chaat',
#        'Fast Food,Tandoor', 'North Indian,Pizzas', 'Ice Cream,Chinese',
#        'Cafe,Italian', 'Thalis', 'South Indian,Pizzas',
#        'North Indian,Thalis', 'Chaat,North Indian', 'Beverages,American',
#        'Bakery,Snacks', 'Chinese,Grill', 'Snacks,Italian-American',
#        'Beverages,North Indian', 'Chinese,Sweets', 'Rajasthani,Punjabi',
#        'Chinese,Chaat', 'Biryani', 'Thalis,Chinese', 'Cafe,North Indian',
#        'Fast Food,Indian', 'Indian,Biryani', 'North Indian,Bihari',
#        'Kerala,Indian', 'Thai,Chinese', 'Mughlai,North Indian',
#        'Sweets,Chinese', 'Biryani,Seafood', 'Chinese,Mexican',
#        'North Indian,Gujarati', 'Tandoor,Indian', 'South Indian,Snacks',
#        'Chinese,Arabian', 'Biryani,Snacks', 'Indian,Desserts',
#        'Indian,Tandoor', 'Indian,Seafood', 'Indian,Street Food',
#        'Chinese,Coastal', 'Kebabs,Chinese', 'Chinese,Juices',
#        'Salads,Fast Food', 'Seafood,North Indian', 'Kerala,South Indian',
#        'Biryani,South Indian', 'South Indian,Arabian', 'Chinese,Tibetan',
#        'Biryani,Mughlai', 'Kebabs,North Indian', 'Indian,Coastal',
#        'Punjabi,North Indian', 'North Indian,Andhra', 'Chinese,Combo',
#        'Thalis,Combo', 'North Eastern,Fast Food', 'Chinese,Pan-Asian',
#        'Street Food,Indian', 'South Indian,Punjabi', 'Desserts,Snacks',
#        'North Indian,Salads', 'Hyderabadi,North Indian',
#        'North Indian,Bengali', 'Kerala,Chinese', 'Biryani,Tandoor',
#        'Beverages,Mughlai', 'Seafood,Coastal', 'Andhra,Biryani',
#        'Andhra,Chinese', 'Coastal,Seafood', 'Arabian,Biryani',
#        'Seafood,Mangalorean', 'Hyderabadi,Biryani', 'Thai,Indian',
#        'Chinese,Italian-American', 'Indian,Mughlai', 'Arabian,Chinese',
#        'Maharashtrian', 'Biryani,Kebabs', 'Nepalese,Chinese',
#        'Bengali,Indian', 'Tibetan,Nepalese', 'Bengali,Sweets',
#        'Desserts,Pizzas', 'Snacks,Tandoor', 'Indian,Asian',
#        'Chinese,Kebabs', 'North Indian,Barbecue', 'North Eastern,Chinese',
#        'Thalis,North Indian', 'Burgers,Pastas', 'Combo,North Indian',
#        'Fast Food,Punjabi', 'Bengali,Biryani', 'Gujarati,Rajasthani',
#        'Asian,North Indian', 'Tandoor,Chinese', 'Gujarati,Thalis',
#        'Indian,Rajasthani', 'Indian,Hyderabadi', 'Punjabi,Indian',
#        'Gujarati,North Indian', 'Italian,South Indian', 'Mexican,Punjabi',
#        'Bengali,Chinese', 'Biryani,Desserts', 'Chinese,Thalis',
#        'Indian,Gujarati', 'Seafood,Mughlai', 'Combo,Snacks',
#        'South Indian,Continental', 'North Indian,Rajasthani',
#        'Chaat,Chinese', 'Mughlai,Indian', 'Maharashtrian,South Indian',
#        'Indian,Combo', 'Chinese,Gujarati', 'Maharashtrian,Street Food',
#        'Mughlai', 'Mughlai,Seafood', 'Biryani,Maharashtrian',
#        'Indian,Maharashtrian', 'Indian,Jain', 'Kerala,Beverages',
#        'Kerala', 'Chinese,Lebanese', 'Arabian,South Indian',
#        'Ice Cream,North Indian', 'Mughlai,Tandoor', 'Beverages,Biryani',
#        'Indian,Kebabs', 'Snacks,North Indian', 'Indian,Thalis',
#        'Kebabs,Fast Food', 'Indian,Sweets', 'North Indian,Seafood',
#        'South Indian,Italian', 'Beverages,Burgers', 'Fast Food,Biryani',
#        'Indian,Salads', 'Beverages,Mexican', 'Snacks,Barbecue',
#        'North Eastern,South Indian', 'Arabian',
#        'North Indian,Italian-American', 'Biryani,Barbecue',
#        'Fast Food,Arabian', 'Indian,Cafe', 'Mughlai,Continental',
#        'Arabian,Fast Food', 'Chinese,Ice Cream', 'Beverages,Punjabi',
#        'Indian,Home Food', 'Snacks,Mughlai', 'Bengali',
#        'Maharashtrian,Biryani', 'Fast Food,Desserts',
#        'Maharashtrian,Kebabs', 'Chinese,Maharashtrian', 'Seafood',
#        'Maharashtrian,Punjabi', 'Punjabi,Tandoor', 'Biryani,Italian',
#        'Desserts,Indian', 'Chinese,Hyderabadi', 'Lebanese,Indian',
#        'Grill,Tandoor', 'Biryani,Andhra', 'North Indian,Kebabs',
#        'Biryani,Hyderabadi', 'Chinese,Kerala', 'American,Andhra',
#        'North Indian,Mangalorean', 'Chinese,Nepalese', 'Tandoor,Biryani',
#        'North Indian,Home Food', 'South Indian,Biryani',
#        'Arabian,Middle Eastern', 'Mangalorean,South Indian',
#        'Chinese,Seafood', 'Chinese,Malaysian', 'North Indian,Ice Cream',
#        'South Indian,Andhra', 'South Indian,Tandoor', 'Arabian,Beverages',
#        'Korean', 'Chettinad,South Indian', 'South Indian,Kerala',
#        'Beverages,Kerala', 'Biryani,Pizzas', 'Fast Food,Sweets',
#        'Nepalese,Tibetan', 'North Indian,Oriya', 'Oriental,Chinese',
#        'Sweets', 'Asian,Burmese', 'Afghani,Barbecue', 'Oriental,Thai',
#        'Gujarati,Snacks', 'Arabian,Tandoor', 'South Indian,Chettinad',
#        'Grill,Chinese', 'Arabian,Indian', 'Andhra', 'Kerala,Biryani',
#        'Lucknowi', 'Chettinad,Thalis', 'Biryani,Combo', 'Biryani,Kerala',
#        'Mangalorean,Kerala', 'Kebabs,South Indian', 'Ice Cream,Desserts',
#        'Continental,Snacks', 'Mexican,Snacks', 'Fast Food,Burgers',
#        'Burgers,Beverages', 'Snacks,Street Food', 'Desserts,Chinese',
#        'Indian,Healthy Food', 'American,Healthy Food', 'American,Juices',
#        'Desserts,Fast Food', 'Chaat,Fast Food', 'Pastas,Fast Food',
#        'Biryani,Gujarati', 'Salads,Healthy Food', 'Salads,Continental',
#        'Healthy Food,North Indian', 'Lebanese', 'Healthy Food,Beverages',
#        'Desserts,Bakery', 'Pastas', 'Continental,Fast Food',
#        'Fast Food,Juices', 'Fast Food,Ice Cream', 'Juices',
#        'Healthy Food,Continental', 'Beverages,Lebanese', 'Snacks,Chaat',
#        'North Indian,Pastas', 'Juices,Fast Food', 'Beverages,Waffle',
#        'Continental,Desserts', 'Beverages,Salads', 'French,Fast Food',
#        'SVANidhi Street Food Vendor,Snacks', 'Pizzas,Combo',
#        'Punjabi,Mexican', 'Lebanese,Middle Eastern', 'Tandoor,Kebabs',
#        'Cafe,Ice Cream', 'Pizzas,Mexican', 'Italian,Mexican',
#        'Arabian,Continental', 'North Indian,American', 'Burgers,Italian',
#        'Grill,Arabian', 'Italian-American,Snacks', 'Arabian,Pizzas',
#        'Cafe,Pizzas', 'Lebanese,Snacks', 'Healthy Food,Pastas',
#        'Arabian,Lebanese', 'Turkish,Middle Eastern', 'British,Beverages',
#        'Mexican,American', 'Healthy Food,American',
#        'Continental,European', 'Biryani,Street Food', 'Kebabs',
#        'Kebabs,Biryani', 'Seafood,Bengali', 'Snacks,Kebabs',
#        'Biryani,Arabian', 'Snacks,Biryani', 'Lebanese,Fast Food',
#        'Bengali,Snacks', 'Beverages,Healthy Food', 'Arabian,Grill',
#        'Mughlai,South Indian', 'Arabian,Snacks', 'American,Asian',
#        'Mughlai,Lucknowi', 'Italian-American,Desserts', 'Chaat,Biryani',
#        'Italian,Mughlai', 'Italian,North Indian',
#        'Italian-American,Indian', 'Coastal,Indian', 'Sweets,South Indian',
#        'Maharashtrian,Chinese', 'Healthy Food,Snacks',
#        'Pizzas,South Indian', 'Chaat,Italian', 'Maharashtrian,Snacks',
#        'South Indian,Sweets', 'Pizzas,Thai', 'South Indian,Street Food',
#        'Sweets,Indian', 'Chaat,Sweets', 'Chaat,Beverages',
#        'South Indian,Chaat', 'Italian,Desserts', 'Waffle,Beverages',
#        'Desserts,Juices', 'Snacks,Ice Cream', 'Lebanese,Pizzas',
#        'Desserts,Ice Cream', 'Indian,Ice Cream', 'Snacks,Burgers',
#        'Street Food,North Indian', 'Italian-American,Pastas',
#        'Italian,Juices', 'Continental,Mexican', 'Snacks,Bakery',
#        'Pizzas,Chaat', 'Continental,Tandoor', 'Grill,American', 'Salads',
#        'Japanese,Chinese', 'Italian,Burgers', 'Gujarati,Punjabi',
#        'North Indian,Middle Eastern', 'Snacks,Desserts',
#        'South Indian,Pastas', 'Desserts,Continental',
#        'Sweets,Continental', 'Indian,Juices', 'Ice Cream,Chaat',
#        'Juices,Snacks', 'Waffle,Ice Cream', 'American,Bakery',
#        'Street Food,Beverages', 'Mexican', 'Bakery,Grill',
#        'Desserts,Italian', 'Burgers,Healthy Food', 'Beverages,Bakery',
#        'Mexican,Italian', 'Desserts,British', 'Continental,Healthy Food',
#        'Thai,Italian', 'Grill,Snacks', 'Biryani,Beverages',
#        'Ice Cream,Fast Food', 'Juices,Ice Cream', 'Lebanese,Tandoor',
#        'Chaat,Ice Cream', 'Beverages,Sweets', 'Waffle,Desserts',
#        'Beverages,Thalis', 'Street Food,Ice Cream', 'Chaat,Salads',
#        'French', 'Beverages,Arabian', 'Juices,American',
#        'Lebanese,Beverages', 'Pastas,Beverages', 'Waffle,Bakery',
#        'Salads,Desserts', 'Seafood,Indian', 'Salads,Italian',
#        'Sweets,Chaat', 'Sweets,Fast Food', 'Thalis,Fast Food',
#        'Rajasthani', 'Combo,Thalis', 'Gujarati,Sweets',
#        'Rajasthani,North Indian', 'Healthy Food,Pizzas',
#        'Home Food,Indian', 'Indian,Bakery', 'Healthy Food,Gujarati',
#        'Oriya,Seafood', 'Desserts,Gujarati', 'Indian,Chaat',
#        'Chaat,Combo', 'Maharashtrian,Indian', 'Ice Cream,Pizzas',
#        'Sweets,Ice Cream', 'South Indian,Gujarati', 'Hyderabadi,Indian',
#        'Beverages,South Indian', 'Desserts,North Indian',
#        'Thalis,Rajasthani', 'Kerala,North Indian', 'Andhra,South Indian',
#        'Chinese,Oriental', 'Sushi,Chinese', 'Fast Food,Continental',
#        'North Indian,Juices', 'Tandoor', 'Indian,American',
#        'Chaat,Street Food', 'Beverages,Bengali', 'American,Turkish',
#        'American,Desserts', 'Bakery,Ice Cream', 'Barbecue',
#        'American,Barbecue', 'Indian,Pastas', 'Steakhouse,Continental',
#        'Pizzas,Barbecue', 'Pastas,Snacks', 'Pizzas,Grill',
#        'South Indian,Rajasthani', 'Street Food,American',
#        'Arabian,Turkish', 'Snacks,Healthy Food', 'South Indian,Combo',
#        'SVANidhi Street Food Vendor,Indian', 'South Indian,Juices',
#        'Kerala,Seafood', 'South Indian,Healthy Food', 'Bakery,Sweets',
#        'Bakery,Chaat', 'Bakery,Burgers',
#        'Bakery,Use Code JUMBO30 to avail', 'Continental,Bakery',
#        'Ice Cream,Bakery', 'Healthy Food,Desserts', 'Bakery,Combo',
#        'Biryani,Ice Cream', 'Lebanese,Chinese', 'Seafood,Asian',
#        'Chaat,Italian-American', 'Pizzas,Lebanese', 'Barbecue,Snacks',
#        'Continental,South Indian', 'Portuguese,African',
#        'Burgers,Mexican', 'Bakery,Street Food', 'Italian-American,Pizzas',
#        'Fast Food,Healthy Food', 'Salads,Snacks', 'Fast Food,Salads',
#        'Pastas,Indian', 'Beverages,Cafe', 'Lebanese,Arabian',
#        'Chinese,Japanese', 'Paan', 'French,Continental',
#        'Burgers,Desserts', 'American,Burgers', 'Pastas,Italian',
#        'American,Thai', 'Thalis,Continental', 'British,Snacks',
#        'Punjabi,Mughlai', 'Tandoor,Fast Food', 'Tandoor,Snacks',
#        'Punjabi,Snacks', 'Mughlai,Hyderabadi', 'Hyderabadi,Mughlai',
#        'Grill,Continental', 'Punjabi,Pastas', 'Chaat,Desserts',
#        'Chinese,Rajasthani', 'Thalis,Beverages', 'Pan-Asian,Japanese',
#        'American,Mexican', 'Mangalorean,Seafood', 'Healthy Food',
#        'Home Food,South Indian', 'Afghani,Indian', 'Barbecue,Italian',
#        'Home Food,North Indian', 'Tandoor,Arabian', 'Indian,Andhra',
#        'Biryani,Healthy Food', 'Barbecue,Mughlai', 'Biryani,Chettinad',
#        'Gujarati,Biryani', 'Home Food,Bengali', 'Naga,Continental',
#        'Bihari,Indian', 'Assamese,Indian', 'Assamese,Bengali',
#        'North Eastern', 'Thalis,Sweets', 'Thai', 'Healthy Food,Juices',
#        'Street Food,Juices', 'Juices,Salads', 'Sweets,Juices',
#        'Street Food,Tex-Mex', 'Afghani,Biryani', 'Andhra,Home Food',
#        'Ice Cream,Ice Cream Cakes', 'Seafood,Chinese', 'American,Biryani',
#        'Mughlai,Snacks', 'Mughlai,Chinese', 'Indian,Thai',
#        'Rajasthani,Maharashtrian', 'Healthy Food,Italian',
#        'Salads,Indian', 'Mexican,Continental', 'Street Food,Italian',
#        'Bakery,Juices', 'Indian,Kerala', 'Kebabs,Indian',
#        'North Indian,Afghani', 'Kebabs,Snacks', 'Andhra,Indian',
#        'Kerala,Snacks', 'Biryani,Thalis', 'Seafood,South Indian',
#        'South Indian,Hyderabadi', 'Juices,Pizzas', 'Seafood,Biryani',
#        'Rajasthani,Snacks', 'Tandoor,Afghani', 'Snacks,Juices',
#        'Grill,Chaat', 'Ice Cream,Indian', 'American,Jain',
#        'Mexican,Salads', 'Bengali,Thalis', 'Healthy Food,Keto',
#        'Mediterranean,Arabian', 'Indian,Biryani - Shivaji Military Hotel',
#        'Maharashtrian,Fast Food', 'Korean,Japanese', 'Japanese,Asian',
#        'Mughlai,Kebabs', 'Japanese,Mediterranean', 'Beverages,Combo',
#        'American,Pastas', 'Steakhouse,Healthy Food', nan], dtype=object)

# %%
df_menu['cuisine'].value_counts()
# Out:
# cuisine
# North Indian,Chinese       27435
# Indian,Chinese             17720
# North Indian               14677
# Indian                     11110
# Chinese,North Indian        7961
#                            ...
# Maharashtrian,Fast Food        1
# Kebabs,Snacks                  1
# South Indian,Hyderabadi        1
# American,Pastas                1
# Steakhouse,Healthy Food        1
# Name: count, Length: 790, dtype: int64

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Get value counts for 'cuisine'
cuisine_counts = df_menu['cuisine'].value_counts()

# Select top 5 cuisines and group the rest as "Others"
top_5_cuisines = cuisine_counts[:5]
other_cuisines_count = cuisine_counts[5:].sum()

# Combine top 5 and "Others" for the pie chart
# Use pd.concat instead of append
pie_chart_data = pd.concat([top_5_cuisines, pd.Series([other_cuisines_count], index=['Others'])])

# Create the pie chart
plt.figure(figsize=(8, 8))  # Adjust figure size if needed
plt.pie(pie_chart_data, labels=pie_chart_data.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Cuisines (Top 5 and Others)')
plt.show()

# %%
df_menu['price'].value_counts()
# Out:
# price
# 120.00    9041
# 100.00    8096
# 80.00     7960
# 150.00    7586
# 90.00     7205
#           ...
# 161.25       1
# 116.67       1
# 421.00       1
# 353.00       1
# 999.00       1
# Name: count, Length: 1209, dtype: int64

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Create bins for the price ranges
bins = [0, 100, 200, 300, 400, 500, float('inf')]  # Last bin for values above 50
labels = ['0-100', '100-200', '200-300', '300-400', '400-500', '500+']

# Convert 'price' column to numeric, handling errors
df_menu['price'] = pd.to_numeric(df_menu['price'], errors='coerce')

# Cut the price column into groups and assign labels
df_menu['price_group'] = pd.cut(df_menu['price'], bins=bins, labels=labels)

# Get value counts for each group
price_group_counts = df_menu['price_group'].value_counts()

# Create the pie chart
plt.figure(figsize=(8, 8))  # Adjust figure size if needed
plt.pie(price_group_counts, labels=price_group_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Price Groups')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Create bins for the price ranges with increments of 100
bins = [0, 100, 200, 300, 400, 500, float('inf')]  # Last bin for values above 500
labels = ['0-100', '100-200', '200-300', '300-400', '400-500', '500+']

# Convert 'price' column to numeric, handling errors
df_menu['price'] = pd.to_numeric(df_menu['price'], errors='coerce')

# Cut the price column into groups and assign labels
df_menu['price_group'] = pd.cut(df_menu['price'], bins=bins, labels=labels)

# Get value counts for each group
price_group_counts = df_menu['price_group'].value_counts()

# Reindex the price_group_counts Series to match the order of labels
price_group_counts = price_group_counts.reindex(labels)

# Create the bar chart
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
ax = price_group_counts.plot(kind='bar', color='green')  # Store the Axes object

# Add value counts on top of the bars
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom')

plt.title('Distribution of Price Groups (Bins of 100)')
plt.xlabel('Price Group')
plt.ylabel('Frequency')
plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent labels from overlapping
plt.show()

# %%
df_menu['f_id'].value_counts()
# Out:
# f_id
# fd1211     3019
# fd47270    3019
# fd47161    2888
# fd28       2888
# fd47222    2884
#            ...
# fd1935        1
# fd1932        1
# fd1931        1
# fd1930        1
# fd1929        1
# Name: count, Length: 2726, dtype: int64

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Get the top 20 f_id values and their counts
top_20_f_id = df_menu['f_id'].value_counts().head(20)

# Create the bar chart
plt.figure(figsize=(12, 6))  # Adjust figure size if needed
ax = top_20_f_id.plot(kind='bar', color='skyblue')

# Add value counts on top of the bars
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom')

plt.title('Top 20 f_id Values in df_menu')
plt.xlabel('f_id')
plt.ylabel('Frequency')
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent labels from overlapping
plt.show()
